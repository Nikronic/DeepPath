# %%
# !python2 -m pip uninstall tensorflow 
# !python2 -m pip install tensorflow-gpu==1.13.1 numpy
# Out:
# Uninstalling tensorflow-2.1.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python2.7/dist-packages/tensorflow-2.1.0.dist-info/*
#     /usr/local/lib/python2.7/dist-packages/tensorflow/*
#     /usr/local/lib/python2.7/dist-packages/tensorflow_core/*
# Proceed (y/n)? y
# y
#   Successfully uninstalled tensorflow-2.1.0
# ...
#      |████████████████████████████████| 345.2MB 36kB/s
# ...
#      |████████████████████████████████| 368kB 33.3MB/s
# ...
#      |████████████████████████████████| 3.2MB 54.1MB/s
# ...
#   Found existing installation: tensorflow-estimator 1.15.0
#     Uninstalling tensorflow-estimator-1.15.0:
#       Successfully uninstalled tensorflow-estimator-1.15.0
#   Found existing installation: tensorboard 2.1.0
#     Uninstalling tensorboard-2.1.0:
# ...

# %%
# !git clone https://github.com/xwhan/DeepPath.git # if you want to use original source code (need fixes) other wise, use below repo
# Out:
# Cloning into 'DeepPath'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 85 (delta 0), reused 2 (delta 0), pack-reused 75
# Unpacking objects: 100% (85/85), done.

# %%
# !git clone https://github.com/Nikronic/DeepPath.git

# %%
# !wget http://cs.ucsb.edu/~xwhan/datasets/NELL-995.zip
# Out:
# --2020-08-01 20:13:56--  http://cs.ucsb.edu/~xwhan/datasets/NELL-995.zip
# Resolving cs.ucsb.edu (cs.ucsb.edu)... 23.185.0.3
# Connecting to cs.ucsb.edu (cs.ucsb.edu)|23.185.0.3|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cs.ucsb.edu/~xwhan/datasets/NELL-995.zip [following]
# --2020-08-01 20:13:57--  https://cs.ucsb.edu/~xwhan/datasets/NELL-995.zip
# Connecting to cs.ucsb.edu (cs.ucsb.edu)|23.185.0.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sites.cs.ucsb.edu/~xwhan/datasets/NELL-995.zip [following]
# --2020-08-01 20:13:57--  https://sites.cs.ucsb.edu/~xwhan/datasets/NELL-995.zip
# Resolving sites.cs.ucsb.edu (sites.cs.ucsb.edu)... 128.111.27.13
# Connecting to sites.cs.ucsb.edu (sites.cs.ucsb.edu)|128.111.27.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 866736281 (827M) [application/zip]
# Saving to: ‘NELL-995.zip’
#
# ...

# %%
# %cd DeepPath/
# !unzip /content/NELL-995.zip
# %cd scripts/

# %%
# !sh pathfinder.sh concept_athleteplaysforteam  # no need to run as found paths are saved in NELL folder - just run below codes

# %%
# !python2 fact_prediction_eval.py concept_athleteplaysforteam
# Out:
# How many paths used:  3
# How many queries:  3177
# Query No.0 of 3177
# left 1
# set(['concept_athlete_aaron_kampman'])
# not such entity
# Query No.1 of 3177
# Query No.2 of 3177
# Query No.3 of 3177
# Query No.4 of 3177
# Query No.5 of 3177
# Query No.6 of 3177
# Query No.7 of 3177
# Query No.8 of 3177
# Query No.9 of 3177
# Query No.10 of 3177
# Query No.11 of 3177
# Query No.12 of 3177
# Query No.13 of 3177
# Query No.14 of 3177
# Query No.15 of 3177
# Query No.16 of 3177
# Query No.17 of 3177
# Query No.18 of 3177
# Query No.19 of 3177
# Query No.20 of 3177
# Query No.21 of 3177
# Query No.22 of 3177
# Query No.23 of 3177
# Query No.24 of 3177
# Query No.25 of 3177
# Query No.26 of 3177
# Query No.27 of 3177
# Query No.28 of 3177
# Query No.29 of 3177
# Query No.30 of 3177
# Query No.31 of 3177
# Query No.32 of 3177
# Query No.33 of 3177
# Query No.34 of 3177
# Query No.35 of 3177
# Query No.36 of 3177
# Query No.37 of 3177
# Query No.38 of 3177
# Query No.39 of 3177
# ...

# %%
# !sh link_prediction_eval.sh concept_athleteplaysforteam
# Out:
# Using TensorFlow backend.
# 25
# How many paths used:  21
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# evaluate.py:41: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   model.fit(np.array(training_features), np.array(train_labels), nb_epoch=300, batch_size=128)
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2020-08-01 20:22:10.094126: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...
